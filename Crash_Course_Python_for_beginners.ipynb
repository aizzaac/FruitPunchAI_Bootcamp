# %% [markdown]
# <a href="https://colab.research.google.com/github/aizzaac/FruitPunchAI_Bootcamp/blob/main/Crash_Course_Python_for_beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crash Course Python for beginners

# %% [markdown]
# To get you up to speed for AI Code, in this notebook we rapidly go over some essential aspects of coding and basics of Python programming. Follow the instructions in this notebook to get a grip of the fundamental concepts. At the end, there will be some exercises to test if you have mastered the basics. **Good luck!**
#
# At the end of this notebook you will be able to:
# -   Work with different types of data
# -   Create and use variables
# -   Create functions and implement existing functions
# -   Use conditional statements and operators
# -   Produce loops
# -   Work with lists and dictionaries

# %% [markdown]
# ## 0. Showing results & Commenting

# %% [markdown]
# First we will start with the basics of using a Jupyter Notebook (an .ipynb file) such as this one we're working on. These notebooks consist of cells that contain regular texts like this one or ones that contain expressions as code blocks, such as the one given below.

# %%
print("Hello Jupyter!")
# Out:
# Hello Jupyter!

# %% [markdown]
# When you run an expression in a notebook (by selecting the code cell and pressing Ctrl+Enter or simply clicking the play button that appears on the left of the cell when you hover over it), the result of the expression is shown below it. Try it out!

# %%
7 + 2
# Out:
# 9

# %%
5 - 1
6 + 10
# Out:
# 16

# %% [markdown]
# Notice that python only displays the result of the last called expression. In order to show multiple results, you have to use the print() function.

# %%
print(5 - 1)
print(6 + 10)
# Out:
# 4
# 16

# %% [markdown]
# You'll notice later that as your code gets more complicated and as you collaborate on a single code with others, you often need explanations and notes within your code. It is also important that whatever note you take does not affect the execution of your code.
#
# For this, Python provides *comments*. You can write comments by putting a # at the beginning of the statement. Such statements won't be executed when you run the code.

# %%
print("This text will be printed")
#print("This won't")

print("You can also comment next to statements to note something about that statement") # like this
# Out:
# This text will be printed
# You can also comment next to statements to note something about that statement

# %% [markdown]
# However if your comment extends one line, you'll need to use multiline strings (which will be ignored by Python since they are not inside a print statement ) using `""" comment """`

# %%
print("You can also comment next to statements to note something about that statement") # like this
# Out:
# You can also comment next to statements to note something about that statement

# %%
print("You can write multiple line comments") # this
# this

"""
Or 
like 
this
"""
print("You can write multiple line comments")
# Out:
# You can write multiple line comments
# You can write multiple line comments

# %% [markdown]
# Awesome! Now that you now the basics of using the Jupyter Notebooks and Python for showing results and taking notes, you're already one step closer to becoming an AI engineer!

# %% [markdown]
# ## 1. Different types of data

# %% [markdown]
# Now we will continue with learning the most essential concept of Python that allow us to play with different types of values such as numbers and texts that may be required to construct algorithms and programs. Such values are our data. There are many different types of data in Python. All with their own special attributes. To keep things clear we will start by introducing the 3 most basic types:
# - Strings
# - Integers
# - Floats

# %% [markdown]
# ### Strings

# %% [markdown]
# A string represents data in the form of texts. Strings consist of characters and is always enclosed with single or double quotes. Or for a string that expands onto multiple lines, you need three double or single quotes.

# %%
print("Hello World")
print('Hello World')
print("""Hello
      World""")
# Out:
# Hello World
# Hello World
# Hello
#       World

# %% [markdown]
# Do you think the line given below will run smoothly?

# %%
print(Hello_World)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-99b68147179c> in <cell line: 1>()
# ----> 1 print(Hello_World)
#
# NameError: name 'Hello_World' is not defined

# %% [markdown]
# No! Without the quotes, Python will think that you are using a variable. If the variable is not defined you get an error, we will come back to this later in the notebook.
#
# There are many other things you can do with strings, but we will cover them in the proceeding sections of this notebook.

# %% [markdown]
# ### Integers

# %% [markdown]
# An integer is a whole number, positive or negative. So a number without decimals.

# %%
print(1000000)
print(-100000)
# Out:
# 1000000
# -100000

# %% [markdown]
# When using large integers in python it is important to know that you can not use commas as separators to make it more readable, but underscores do work for that purpose.

# %%
print(1_000_000)
print(1,000,000)
# Out:
# 1000000
# 1 0 0

# %% [markdown]
# ### Floats

# %% [markdown]
# Floats are numbers with decimals, again positive or negative. Every number that is followed with a "**.**" will be considered a float.

# %%
print(3.3)
print(-3.3)
# Out:
# 3.3
# -3.3

# %% [markdown]
# Make sure to always use a  .  as a decimal point. Commas in python are used for the separation of values.

# %%
print(3,3)
# Out:
# 3 3

# %% [markdown]
# ### Data Types - Summary
#
# There are other data types in Python that are often used. The ones explained in these sections are the atomic data types in Python. It is important to be aware of what is the type of your data and to be coherent in terms of types. In order to quickly check what type of data you are dealing with you can use the *type()* function

# %%
type(13.)
# Out:
# float

# %%
type(13)
# Out:
# int

# %%
type("13")
# Out:
# str

# %% [markdown]
# ### Changing types

# %% [markdown]
# Sometimes in order to fit your data into a certain algorithm, you will need to change the type of the data. This is possible with typecasting functions:
# - str(): returns a string
# - int(): returns an integer
# - float(): returns a float

# %%
print(10/3)
type(10/3)
# Out:
# 3.3333333333333335
# float

# %%
print(int(10/3))
type(int(10/3))
# Out:
# 3
# int

# %%
print(str(10/3))
type(str(10/3))
# Out:
# 3.3333333333333335
# str

# %% [markdown]
# ### Basic calculations

# %% [markdown]
# Basic calculations combine two values with one operator in between them. Some straightforward operators are:
#
#     +   addition
#     -   subtraction
#     *   multiplication
#     /   division
#     //  integer division
#     **  power
#     %   modulo
#
# Here are some examples:

# %%
print(14+5)
print(14-5)
print(14*5)
print(14/5)
print(14//5)
print(14**5)
print(14%5)
# Out:
# 19
# 9
# 70
# 2.8
# 2
# 537824
# 4

# %% [markdown]
# We will assume this does not need any more explanation. Only the integer division and modulo might be unfamiliar.
#
# The integer division (//) is simply a division that rounds down to a whole number. The modulo operator (%) takes the remainder of a division. In very simplistic terms: if we have 14 cookies which we have to divide over 5 children, each child gets 2 cookies. And we still have 4 cookies left. Thus, dividing 14 by 5 as an integer division is 2, while 14 modulo 5 is the remainder 4.

# %% [markdown]
# So far, so good. Now that you know about the different types of data we can continue to the next chapter

# %% [markdown]
# ## 2. Variables

# %% [markdown]
# In order to handle the data values in our program systematically, we need flexible and stable structures. These are called variables in Python. To make a variable you are free to choose the names as you like them, provided that you follow a few simple rules, namely:
#
# - A variable name must consist of only letters, digits, and/or underscores
# - A variable name must start with a letter or an underscore
# - A variable name should not be a reserved word
#
# "Reserved words" are:
#
# <div class="verbatim"><pre>
# and       del       from      not       while
# as        elif      global    or        with
# assert    else      if        pass      yield
# break     except    import    print
# class     exec      in        raise
# continue  finally   is        return
# def       for       lambda    try</pre></div>

# %% [markdown]
# Variables are assigned values with the equal sign (=). Once a variable is created python will store this in memory to be called whenever you like.

# %%
x = 3.14159265
y = 7.5
z = x * y * y
print( z )
# Out:
# 176.71458656250002

# %%
pi = 3.14159265
radius = 7.5
area_of_circle = pi * radius * radius
print( area_of_circle )
# Out:
# 176.71458656250002

# %% [markdown]
# As you can see python does not care what name you give to your variables. We recommend you use clear and precise language to describe your variables. Later when you will be working with more complex algorithms or together with other people this will benefit you greatly.

# %%
a = 1
b = 4
c = "1"
d = "4"
print( a + b )
print( c + d )
print( a * c )
# Out:
# 5
# 14
# 1

# %% [markdown]
# It is important to check that you are using the right types of data when creating variables.
#
# For example, look at the `a * c`statement above it does print the correct results but what is it's type?

# %%
type( a * c )
# Out:
# str

# %% [markdown]
# Although the result is correct the manner in which it is calculated might not be right. See what happens when you try to use it for further calculations.

# %%
print((a * c) * 3)
# Out:
# 111

# %% [markdown]
# ## 3. Operators

# %% [markdown]
# As you can see from the result above, multiplying the result from `a*c` multiplied 1 as a string, as we checked in the cell above that the result from `a*c` was a string. Hence, it is important to keep track of the types of your variables and data to ensure that you will get the result you expect.

# %% [markdown]
# In order to perform operations on variables and values, we need some operators as in mathematics. Python has 7 groups of operators and we will go over 6 of them in this notebook. Some of these operators will make more sense as you progress through this notebook with examples of these operators shown inside the example codes.
#
#
# 1. Arithmetic Operators
#     * Addition	`x + y	`
#     * Subtraction	`x - y	`
#     * Multiplication	`x * y	`
#     * Division	`x / y	`
#     * Modulus	`x % y	`
#     * Exponentiation	`x ** y	`
#
# 2. Assignment Operators
#     * Asign	`x = 5	`
#     * Sum with itself and assign	`x += 3` (x  = x + 3)
#     * Subtract from itself and assign	`x -= 3` (x  = x - 3)
#     * Multiply and assign	`x *= 3` (x  = x * 3)
#     * Divide and assign	`x /= 3` (x  = x / 3)
#     * Take the modulus and assign	`x %= 3`	(x = x % 3)
#     * Take the exponential and assign `x **= 3`	(x = x ** 3)
#
# 3. Comparison Operators
#     * Equal	`x == y`
#     * Not equal	`x != y`
#     * Greater than	`x > y	`
#     * Less than	`x < y	`
#     * Greater than or equal to `	x >= y`
#     * Less than or equal to `	x <= y`
#
# 4. Logical Operators
#     * `and` True if both statements are true	`x < 5 and  x < 10	`
#     * `or` True if one of the statements is true `	x < 5 or x < 4`
#     * `not`	Reverse the result, returns False if the result is true	`not(x < 5 and x < 10)`
#
# 5. Identity Operators
#
#     * `is` 	True if both variables are the same object	`x is y`
#     * `is not` True if both variables are not the same object	`x is not y`
#
# 6. Membership operators
#
#     * `in`  True if a sequence with the specified value is present in the object	`x in y	`
#     * `not in`  True if a sequence with the specified value is not present in the object	`x not in y`

# %% [markdown]
# ## 4. Functions

# %% [markdown]
# As your programs get longer and more complicated, you'll realize you may need to perform the same non-trivial operation multiple times using different values. For that, programming languages including Python provide *functions*.
#
# A function is a block of code that can be defined somewhere in the code and used in multiple statements by only referencing its name and only runs when it is called.
#
# In order to write your own functions, you need to define the name of the function, the input values (its parameters), and the value it outputs (returns). A function is defined as the following in Python:
#
#     def <function_name>( <parameter_list> ):
#         <statements>
#         <return>

# %% [markdown]
# For example if you want to calculate the volume of a cylinder different cylinders, instead of writing the formula explicitly every  time you can define a function as the one given below. As parameters, we pass the values that change according to the features of the cylinder we operate on. The values we pass as parameters are used as the variable values inside the function.

# %%
def volume_of_cylinder(pi, radius, height):
    volume = pi * radius**2 * height
    return volume

# %% [markdown]
# It is important that all statements that belong to the function are indented inside the function. This is because Python is **whitespace sensitive** so indentation defines the code blocks.

# %%
def volume_of_cylinder_false(pi, radius, height):
    volume = pi * radius**2 * height
  return volume
# Out:
#   File "<tokenize>", line 3
#     return volume
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
volume_of_cylinder(3.14159265, 3, 15) # pi = 3.14159265, radius = 3, height = 15
# Out:
# 424.11500775

# %% [markdown]
# Once you created a function and variables you can play around with it to make it easier to use. For example, it is easier to store the value of pi into a variable so you won't have to type it out every time. Especially for known constants such as Pi, it is good practice to define the variable all capitalized so the reader knows it's value won't change throughout the code, so it's a *constant*

# %%
PI = 3.14159265
print("Volume:",volume_of_cylinder(PI, 3, 15))
print("Volume:",volume_of_cylinder(PI, 1, 100))
print("Volume:",volume_of_cylinder(PI, 20, 1))
# Out:
# Volume: 424.11500775
# Volume: 314.159265
# Volume: 1256.63706

# %% [markdown]
# Python also features a lot of built-in functions. You can find them all here: https://docs.python.org/3/library/functions.html
#
# To give some easy examples:

# %%
print(max([.0, 4, 10, 200, 56]))
print(min([.0, 4, 10, 200, 56]))
print(sum([.0, 4, 10, 200, 56]))
print(len([.0, 4, 10, 200, 56]))
# Out:
# 200
# 0.0
# 270.0
# 5

# %% [markdown]
# ## 5. Conditions

# %% [markdown]
# Now that you know how to make a simple function we can go on to make things a bit more fun. You'll notice that for specific values or conditions you might want to have alternative numbers or operations inside the same program. For example consider you write a program that calculates the weight of a person, then the formula you will use in different planets has to be different because of the different gravitational force values. Conditions and if statements provide this functionality using logical rules.
#
# With conditions, you can write your functions in such a way that it will only return an output if certain requirements are met. To do this we use comparisons with  logical conditions:
#
#     <    less than
#     <=   less than or equal to
#     ==   equal to
#     >=   equal to or greater than
#     >    greater than
#     !=   not equal

# %%
EARTH_GRAVITY = 9.8
MOON_GRAVITY = 1.62

def calculate_weight(mass, planet):
    gravity = 0
    if planet == 'Earth':
        gravity = EARTH_GRAVITY
    if planet == 'Moon':
        gravity = MOON_GRAVITY

    return mass * gravity

# %% [markdown]
# Comparisons are also used to trigger functions.

# %%
def tweet_to_long(tweet):
    if len(tweet) <= 140:
        return tweet
    else:
        return "Tweet is too long"

# %%
tweet_to_long("So today I went to the park with my dog. I saw a guy on a BMX, he did some very cool tricks. After the park we went for ice cream, I got vanilla and strawberry.")
# Out:
# 'Tweet is too long'

# %%
tweet_to_long("So today I went to the park with my dog. I saw a guy on a BMX, he did some very cool tricks")
# Out:
# 'So today I went to the park with my dog. I saw a guy on a BMX, he did some very cool tricks'

# %% [markdown]
# Besides comparison signs, there are also operators you can use. This is often useful when working with text data.
#
# - **in**: returns True when the parameter is in text
# - **not in**: returns True when the parameter is not in the text
# - **and**: returns True when both values are True
# - **or**: returns True when one of the values is True
# - **not**: reverses a True to a False

# %%
def letter_A(text):
    if "a" in text:
        return "Booyah!"
    else:
        return ":("

letter_A("Hello World")
# Out:
# ':('

# %%
def not_letter_A(text):
    if "a" not in text:
        return "Booyah!"
    else:
        return ":("

not_letter_A("Hello World")
# Out:
# 'Booyah!'

# %%
def both_A_and_B(text):
    if "a" in text and "b" in text:
        return "Booyah!"
    else:
        return ":("
    
both_A_and_B("Do you know Ali-B")
# Out:
# ':('

# %% [markdown]
# OOPS! that's weird. Even though the letter a and b are in the text the function still returns a sad face. The reason for this is that python is sensitive to capital letters. So an 'a' is not the same as an 'A'. To fix this we can make use of the **or** function.

# %%
def both_A_and_B(text):
    if "a" or "A" in text and "b" or "B" in text:
        return "Booyah!"
    else:
        return ":("
    
both_A_and_B("Do you know Ali-B")
# Out:
# 'Booyah!'

# %% [markdown]
# It works! How about this one, do you think it will work?

# %%
def both_A_and_B(text):
    answer = 'Default'
    if "a" or "A" in text and "b" or "B" in text:
        answer = "Booyah!"
    else:
        a = 1
    answer = ":("
    
    return answer
both_A_and_B("Do you know Ali-B")
# Out:
# ':('

# %% [markdown]
# Notice that the statement `answer = ':('` misses a level of indentation to be inside the block of the if statement. Therefore no matter the condition it will be executed inside the code block of the function. To fix the issue, simply indent the statement by 1 level and align it with `a = 1`

# %% [markdown]
# ## 6. Loops

# %% [markdown]
# Another thing you'll notice you'do quite a lot in programming is repeating the same procedure several times. With loops, you can repeat any task written inside the loop countless times. There are two main types of loops in Python: *while* and *for* loops. They essentially have the same functionality but the ways in which they are written and operate are different.

# %% [markdown]
# ### While Loops
# Starting with *while* loops, they repeate the statements inside them while a given condition is correct. The format of while the statement should be as the following,
#
#
# ```
# while <conditions>:
#     <statements>
# ```
#
#
#
# It comes in very handy when you for example need to write out the entire lyrics of "around the world" by Daft Punk.

# %%
def daft_punk():
    num = 1
    while num <= 72:
        print(num,"- Around the world, around the world")
        num += 1

# %%
daft_punk()
# Out:
# 1 - Around the world, around the world
# 2 - Around the world, around the world
# 3 - Around the world, around the world
# 4 - Around the world, around the world
# 5 - Around the world, around the world
# 6 - Around the world, around the world
# 7 - Around the world, around the world
# 8 - Around the world, around the world
# 9 - Around the world, around the world
# 10 - Around the world, around the world
# 11 - Around the world, around the world
# 12 - Around the world, around the world
# 13 - Around the world, around the world
# 14 - Around the world, around the world
# 15 - Around the world, around the world
# 16 - Around the world, around the world
# 17 - Around the world, around the world
# 18 - Around the world, around the world
# 19 - Around the world, around the world
# 20 - Around the world, around the world
# 21 - Around the world, around the world
# 22 - Around the world, around the world
# 23 - Around the world, around the world
# 24 - Around the world, around the world
# 25 - Around the world, around the world
# 26 - Around the world, around the world
# 27 - Around the world, around the world
# 28 - Around the world, around the world
# 29 - Around the world, around the world
# 30 - Around the world, around the world
# 31 - Around the world, around the world
# 32 - Around the world, around the world
# 33 - Around the world, around the world
# 34 - Around the world, around the world
# 35 - Around the world, around the world
# 36 - Around the world, around the world
# 37 - Around the world, around the world
# 38 - Around the world, around the world
# 39 - Around the world, around the world
# 40 - Around the world, around the world
# 41 - Around the world, around the world
# 42 - Around the world, around the world
# 43 - Around the world, around the world
# 44 - Around the world, around the world
# 45 - Around the world, around the world
# 46 - Around the world, around the world
# 47 - Around the world, around the world
# 48 - Around the world, around the world
# 49 - Around the world, around the world
# 50 - Around the world, around the world
# 51 - Around the world, around the world
# 52 - Around the world, around the world
# 53 - Around the world, around the world
# 54 - Around the world, around the world
# 55 - Around the world, around the world
# 56 - Around the world, around the world
# 57 - Around the world, around the world
# 58 - Around the world, around the world
# 59 - Around the world, around the world
# 60 - Around the world, around the world
# 61 - Around the world, around the world
# 62 - Around the world, around the world
# 63 - Around the world, around the world
# 64 - Around the world, around the world
# 65 - Around the world, around the world
# 66 - Around the world, around the world
# 67 - Around the world, around the world
# 68 - Around the world, around the world
# 69 - Around the world, around the world
# 70 - Around the world, around the world
# 71 - Around the world, around the world
# 72 - Around the world, around the world

# %% [markdown]
# Very handy but you have to be careful. You want to look out for endless loops. An endless loop has no clear ending point which causes it to keep running until it's killed manually. So it is important that you always specify when the loop is finished.

# %% [markdown]
# If by mistake you create an endless loop you will have to kill the kernel. You can do this by clicking on "Kernel" in the left top of your screen and proceed to click on "shut down kernel". Let's try this out:

# %%
def endless_loop():
    num = 1
    while num >= 0:
        print(num,"- Around the world, around the world")
        num += 1

# %%
endless_loop()
# Out:
# 1 - Around the world, around the world
# 2 - Around the world, around the world
# 3 - Around the world, around the world
# 4 - Around the world, around the world
# 5 - Around the world, around the world
# 6 - Around the world, around the world
# 7 - Around the world, around the world
# 8 - Around the world, around the world
# 9 - Around the world, around the world
# 10 - Around the world, around the world
# 11 - Around the world, around the world
# 12 - Around the world, around the world
# 13 - Around the world, around the world
# 14 - Around the world, around the world
# 15 - Around the world, around the world
# 16 - Around the world, around the world
# 17 - Around the world, around the world
# 18 - Around the world, around the world
# 19 - Around the world, around the world
# 20 - Around the world, around the world
# 21 - Around the world, around the world
# 22 - Around the world, around the world
# 23 - Around the world, around the world
# 24 - Around the world, around the world
# 25 - Around the world, around the world
# 26 - Around the world, around the world
# 27 - Around the world, around the world
# 28 - Around the world, around the world
# 29 - Around the world, around the world
# 30 - Around the world, around the world
# 31 - Around the world, around the world
# 32 - Around the world, around the world
# 33 - Around the world, around the world
# 34 - Around the world, around the world
# 35 - Around the world, around the world
# 36 - Around the world, around the world
# 37 - Around the world, around the world
# 38 - Around the world, around the world
# 39 - Around the world, around the world
# 40 - Around the world, around the world
# 41 - Around the world, around the world
# 42 - Around the world, around the world
# 43 - Around the world, around the world
# 44 - Around the world, around the world
# 45 - Around the world, around the world
# 46 - Around the world, around the world
# 47 - Around the world, around the world
# 48 - Around the world, around the world
# 49 - Around the world, around the world
# 50 - Around the world, around the world
# 51 - Around the world, around the world
# 52 - Around the world, around the world
# 53 - Around the world, around the world
# 54 - Around the world, around the world
# 55 - Around the world, around the world
# 56 - Around the world, around the world
# 57 - Around the world, around the world
# 58 - Around the world, around the world
# 59 - Around the world, around the world
# 60 - Around the world, around the world
# 61 - Around the world, around the world
# 62 - Around the world, around the world
# 63 - Around the world, around the world
# 64 - Around the world, around the world
# 65 - Around the world, around the world
# 66 - Around the world, around the world
# 67 - Around the world, around the world
# 68 - Around the world, around the world
# 69 - Around the world, around the world
# 70 - Around the world, around the world
# 71 - Around the world, around the world
# 72 - Around the world, around the world
# 73 - Around the world, around the world
# 74 - Around the world, around the world
# 75 - Around the world, around the world
# 76 - Around the world, around the world
# 77 - Around the world, around the world
# 78 - Around the world, around the world
# 79 - Around the world, around the world
# 80 - Around the world, around the world
# 81 - Around the world, around the world
# 82 - Around the world, around the world
# 83 - Around the world, around the world
# 84 - Around the world, around the world
# 85 - Around the world, around the world
# 86 - Around the world, around the world
# 87 - Around the world, around the world
# 88 - Around the world, around the world
# 89 - Around the world, around the world
# 90 - Around the world, around the world
# 91 - Around the world, around the world
# 92 - Around the world, around the world
# 93 - Around the world, around the world
# 94 - Around the world, around the world
# 95 - Around the world, around the world
# 96 - Around the world, around the world
# 97 - Around the world, around the world
# 98 - Around the world, around the world
# 99 - Around the world, around the world
# 100 - Around the world, around the world
# 101 - Around the world, around the world
# 102 - Around the world, around the world
# 103 - Around the world, around the world
# 104 - Around the world, around the world
# 105 - Around the world, around the world
# 106 - Around the world, around the world
# 107 - Around the world, around the world
# 108 - Around the world, around the world
# 109 - Around the world, around the world
# 110 - Around the world, around the world
# 111 - Around the world, around the world
# 112 - Around the world, around the world
# 113 - Around the world, around the world
# 114 - Around the world, around the world
# 115 - Around the world, around the world
# 116 - Around the world, around the world
# 117 - Around the world, around the world
# 118 - Around the world, around the world
# 119 - Around the world, around the world
# 120 - Around the world, around the world
# 121 - Around the world, around the world
# 122 - Around the world, around the world
# 123 - Around the world, around the world
# 124 - Around the world, around the world
# 125 - Around the world, around the world
# 126 - Around the world, around the world
# 127 - Around the world, around the world
# 128 - Around the world, around the world
# 129 - Around the world, around the world
# 130 - Around the world, around the world
# 131 - Around the world, around the world
# 132 - Around the world, around the world
# 133 - Around the world, around the world
# 134 - Around the world, around the world
# 135 - Around the world, around the world
# 136 - Around the world, around the world
# 137 - Around the world, around the world
# 138 - Around the world, around the world
# 139 - Around the world, around the world
# 140 - Around the world, around the world
# 141 - Around the world, around the world
# 142 - Around the world, around the world
# 143 - Around the world, around the world
# 144 - Around the world, around the world
# 145 - Around the world, around the world
# 146 - Around the world, around the world
# 147 - Around the world, around the world
# 148 - Around the world, around the world
# 149 - Around the world, around the world
# 150 - Around the world, around the world
# 151 - Around the world, around the world
# 152 - Around the world, around the world
# 153 - Around the world, around the world
# 154 - Around the world, around the world
# 155 - Around the world, around the world
# 156 - Around the world, around the world
# 157 - Around the world, around the world
# 158 - Around the world, around the world
# 159 - Around the world, around the world
# 160 - Around the world, around the world
# 161 - Around the world, around the world
# 162 - Around the world, around the world
# 163 - Around the world, around the world
# 164 - Around the world, around the world
# 165 - Around the world, around the world
# 166 - Around the world, around the world
# 167 - Around the world, around the world
# 168 - Around the world, around the world
# 169 - Around the world, around the world
# 170 - Around the world, around the world
# 171 - Around the world, around the world
# 172 - Around the world, around the world
# 173 - Around the world, around the world
# 174 - Around the world, around the world
# 175 - Around the world, around the world
# 176 - Around the world, around the world
# 177 - Around the world, around the world
# 178 - Around the world, around the world
# 179 - Around the world, around the world
# 180 - Around the world, around the world
# 181 - Around the world, around the world
# 182 - Around the world, around the world
# 183 - Around the world, around the world
# 184 - Around the world, around the world
# 185 - Around the world, around the world
# 186 - Around the world, around the world
# 187 - Around the world, around the world
# 188 - Around the world, around the world
# 189 - Around the world, around the world
# 190 - Around the world, around the world
# 191 - Around the world, around the world
# 192 - Around the world, around the world
# 193 - Around the world, around the world
# 194 - Around the world, around the world
# 195 - Around the world, around the world
# 196 - Around the world, around the world
# 197 - Around the world, around the world
# 198 - Around the world, around the world
# 199 - Around the world, around the world
# 200 - Around the world, around the world
# 201 - Around the world, around the world
# 202 - Around the world, around the world
# 203 - Around the world, around the world
# 204 - Around the world, around the world
# 205 - Around the world, around the world
# 206 - Around the world, around the world
# 207 - Around the world, around the world
# 208 - Around the world, around the world
# 209 - Around the world, around the world
# 210 - Around the world, around the world
# 211 - Around the world, around the world
# 212 - Around the world, around the world
# 213 - Around the world, around the world
# 214 - Around the world, around the world
# 215 - Around the world, around the world
# 216 - Around the world, around the world
# 217 - Around the world, around the world
# 218 - Around the world, around the world
# 219 - Around the world, around the world
# 220 - Around the world, around the world
# 221 - Around the world, around the world
# 222 - Around the world, around the world
# 223 - Around the world, around the world
# 224 - Around the world, around the world
# 225 - Around the world, around the world
# 226 - Around the world, around the world
# 227 - Around the world, around the world
# 228 - Around the world, around the world
# 229 - Around the world, around the world
# 230 - Around the world, around the world
# 231 - Around the world, around the world
# 232 - Around the world, around the world
# 233 - Around the world, around the world
# 234 - Around the world, around the world
# 235 - Around the world, around the world
# 236 - Around the world, around the world
# 237 - Around the world, around the world
# 238 - Around the world, around the world
# 239 - Around the world, around the world
# 240 - Around the world, around the world
# 241 - Around the world, around the world
# 242 - Around the world, around the world
# 243 - Around the world, around the world
# 244 - Around the world, around the world
# 245 - Around the world, around the world
# 246 - Around the world, around the world
# 247 - Around the world, around the world
# 248 - Around the world, around the world
# 249 - Around the world, around the world
# 250 - Around the world, around the world
# 251 - Around the world, around the world
# 252 - Around the world, around the world
# 253 - Around the world, around the world
# 254 - Around the world, around the world
# 255 - Around the world, around the world
# 256 - Around the world, around the world
# 257 - Around the world, around the world
# 258 - Around the world, around the world
# 259 - Around the world, around the world
# 260 - Around the world, around the world
# 261 - Around the world, around the world
# 262 - Around the world, around the world
# 263 - Around the world, around the world
# 264 - Around the world, around the world
# 265 - Around the world, around the world
# 266 - Around the world, around the world
# 267 - Around the world, around the world
# 268 - Around the world, around the world
# 269 - Around the world, around the world
# 270 - Around the world, around the world
# 271 - Around the world, around the world
# 272 - Around the world, around the world
# 273 - Around the world, around the world
# 274 - Around the world, around the world
# 275 - Around the world, around the world
# 276 - Around the world, around the world
# 277 - Around the world, around the world
# 278 - Around the world, around the world
# 279 - Around the world, around the world
# 280 - Around the world, around the world
# 281 - Around the world, around the world
# 282 - Around the world, around the world
# 283 - Around the world, around the world
# 284 - Around the world, around the world
# 285 - Around the world, around the world
# 286 - Around the world, around the world
# 287 - Around the world, around the world
# 288 - Around the world, around the world
# 289 - Around the world, around the world
# 290 - Around the world, around the world
# 291 - Around the world, around the world
# 292 - Around the world, around the world
# 293 - Around the world, around the world
# 294 - Around the world, around the world
# 295 - Around the world, around the world
# 296 - Around the world, around the world
# 297 - Around the world, around the world
# 298 - Around the world, around the world
# 299 - Around the world, around the world
# 300 - Around the world, around the world
# 301 - Around the world, around the world
# 302 - Around the world, around the world
# 303 - Around the world, around the world
# 304 - Around the world, around the world
# 305 - Around the world, around the world
# 306 - Around the world, around the world
# 307 - Around the world, around the world
# 308 - Around the world, around the world
# 309 - Around the world, around the world
# 310 - Around the world, around the world
# 311 - Around the world, around the world
# 312 - Around the world, around the world
# 313 - Around the world, around the world
# 314 - Around the world, around the world
# 315 - Around the world, around the world
# 316 - Around the world, around the world
# 317 - Around the world, around the world
# 318 - Around the world, around the world
# 319 - Around the world, around the world
# 320 - Around the world, around the world
# 321 - Around the world, around the world
# 322 - Around the world, around the world
# 323 - Around the world, around the world
# 324 - Around the world, around the world
# 325 - Around the world, around the world
# 326 - Around the world, around the world
# 327 - Around the world, around the world
# 328 - Around the world, around the world
# 329 - Around the world, around the world
# 330 - Around the world, around the world
# 331 - Around the world, around the world
# 332 - Around the world, around the world
# 333 - Around the world, around the world
# 334 - Around the world, around the world
# 335 - Around the world, around the world
# 336 - Around the world, around the world
# 337 - Around the world, around the world
# 338 - Around the world, around the world
# 339 - Around the world, around the world
# 340 - Around the world, around the world
# 341 - Around the world, around the world
# 342 - Around the world, around the world
# 343 - Around the world, around the world
# 344 - Around the world, around the world
# 345 - Around the world, around the world
# 346 - Around the world, around the world
# 347 - Around the world, around the world
# 348 - Around the world, around the world
# 349 - Around the world, around the world
# 350 - Around the world, around the world
# 351 - Around the world, around the world
# 352 - Around the world, around the world
# 353 - Around the world, around the world
# 354 - Around the world, around the world
# 355 - Around the world, around the world
# 356 - Around the world, around the world
# 357 - Around the world, around the world
# 358 - Around the world, around the world
# 359 - Around the world, around the world
# 360 - Around the world, around the world
# 361 - Around the world, around the world
# 362 - Around the world, around the world
# 363 - Around the world, around the world
# 364 - Around the world, around the world
# 365 - Around the world, around the world
# 366 - Around the world, around the world
# 367 - Around the world, around the world
# 368 - Around the world, around the world
# 369 - Around the world, around the world
# 370 - Around the world, around the world
# 371 - Around the world, around the world
# 372 - Around the world, around the world
# 373 - Around the world, around the world
# 374 - Around the world, around the world
# 375 - Around the world, around the world
# 376 - Around the world, around the world
# 377 - Around the world, around the world
# 378 - Around the world, around the world
# 379 - Around the world, around the world
# 380 - Around the world, around the world
# 381 - Around the world, around the world
# 382 - Around the world, around the world
# 383 - Around the world, around the world
# 384 - Around the world, around the world
# 385 - Around the world, around the world
# 386 - Around the world, around the world
# 387 - Around the world, around the world
# 388 - Around the world, around the world
# 389 - Around the world, around the world
# 390 - Around the world, around the world
# 391 - Around the world, around the world
# 392 - Around the world, around the world
# 393 - Around the world, around the world
# 394 - Around the world, around the world
# 395 - Around the world, around the world
# 396 - Around the world, around the world
# 397 - Around the world, around the world
# 398 - Around the world, around the world
# 399 - Around the world, around the world
# 400 - Around the world, around the world
# 401 - Around the world, around the world
# 402 - Around the world, around the world
# 403 - Around the world, around the world
# 404 - Around the world, around the world
# 405 - Around the world, around the world
# 406 - Around the world, around the world
# 407 - Around the world, around the world
# 408 - Around the world, around the world
# 409 - Around the world, around the world
# 410 - Around the world, around the world
# 411 - Around the world, around the world
# 412 - Around the world, around the world
# 413 - Around the world, around the world
# 414 - Around the world, around the world
# 415 - Around the world, around the world
# 416 - Around the world, around the world
# 417 - Around the world, around the world
# 418 - Around the world, around the world
# 419 - Around the world, around the world
# 420 - Around the world, around the world
# 421 - Around the world, around the world
# 422 - Around the world, around the world
# 423 - Around the world, around the world
# 424 - Around the world, around the world
# 425 - Around the world, around the world
# 426 - Around the world, around the world
# 427 - Around the world, around the world
# 428 - Around the world, around the world
# 429 - Around the world, around the world
# 430 - Around the world, around the world
# 431 - Around the world, around the world
# 432 - Around the world, around the world
# 433 - Around the world, around the world
# 434 - Around the world, around the world
# 435 - Around the world, around the world
# 436 - Around the world, around the world
# 437 - Around the world, around the world
# 438 - Around the world, around the world
# 439 - Around the world, around the world
# 440 - Around the world, around the world
# 441 - Around the world, around the world
# 442 - Around the world, around the world
# 443 - Around the world, around the world
# 444 - Around the world, around the world
# 445 - Around the world, around the world
# 446 - Around the world, around the world
# 447 - Around the world, around the world
# 448 - Around the world, around the world
# 449 - Around the world, around the world
# 450 - Around the world, around the world
# 451 - Around the world, around the world
# 452 - Around the world, around the world
# 453 - Around the world, around the world
# 454 - Around the world, around the world
# 455 - Around the world, around the world
# 456 - Around the world, around the world
# 457 - Around the world, around the world
# 458 - Around the world, around the world
# 459 - Around the world, around the world
# 460 - Around the world, around the world
# 461 - Around the world, around the world
# 462 - Around the world, around the world
# 463 - Around the world, around the world
# 464 - Around the world, around the world
# 465 - Around the world, around the world
# 466 - Around the world, around the world
# 467 - Around the world, around the world
# 468 - Around the world, around the world
# 469 - Around the world, around the world
# 470 - Around the world, around the world
# 471 - Around the world, around the world
# 472 - Around the world, around the world
# 473 - Around the world, around the world
# 474 - Around the world, around the world
# 475 - Around the world, around the world
# 476 - Around the world, around the world
# 477 - Around the world, around the world
# 478 - Around the world, around the world
# 479 - Around the world, around the world
# 480 - Around the world, around the world
# 481 - Around the world, around the world
# 482 - Around the world, around the world
# 483 - Around the world, around the world
# 484 - Around the world, around the world
# 485 - Around the world, around the world
# 486 - Around the world, around the world
# 487 - Around the world, around the world
# 488 - Around the world, around the world
# 489 - Around the world, around the world
# 490 - Around the world, around the world
# 491 - Around the world, around the world
# 492 - Around the world, around the world
# 493 - Around the world, around the world
# 494 - Around the world, around the world
# 495 - Around the world, around the world
# 496 - Around the world, around the world
# 497 - Around the world, around the world
# 498 - Around the world, around the world
# 499 - Around the world, around the world
# 500 - Around the world, around the world
# 501 - Around the world, around the world
# 502 - Around the world, around the world
# 503 - Around the world, around the world
# 504 - Around the world, around the world
# 505 - Around the world, around the world
# 506 - Around the world, around the world
# 507 - Around the world, around the world
# 508 - Around the world, around the world
# 509 - Around the world, around the world
# 510 - Around the world, around the world
# 511 - Around the world, around the world
# 512 - Around the world, around the world
# 513 - Around the world, around the world
# 514 - Around the world, around the world
# 515 - Around the world, around the world
# 516 - Around the world, around the world
# 517 - Around the world, around the world
# 518 - Around the world, around the world
# 519 - Around the world, around the world
# 520 - Around the world, around the world
# 521 - Around the world, around the world
# 522 - Around the world, around the world
# 523 - Around the world, around the world
# 524 - Around the world, around the world
# 525 - Around the world, around the world
# 526 - Around the world, around the world
# 527 - Around the world, around the world
# 528 - Around the world, around the world
# 529 - Around the world, around the world
# 530 - Around the world, around the world
# 531 - Around the world, around the world
# 532 - Around the world, around the world
# 533 - Around the world, around the world
# 534 - Around the world, around the world
# 535 - Around the world, around the world
# 536 - Around the world, around the world
# 537 - Around the world, around the world
# 538 - Around the world, around the world
# 539 - Around the world, around the world
# 540 - Around the world, around the world
# 541 - Around the world, around the world
# 542 - Around the world, around the world
# 543 - Around the world, around the world
# 544 - Around the world, around the world
# 545 - Around the world, around the world
# 546 - Around the world, around the world
# 547 - Around the world, around the world
# 548 - Around the world, around the world
# 549 - Around the world, around the world
# 550 - Around the world, around the world
# 551 - Around the world, around the world
# 552 - Around the world, around the world
# 553 - Around the world, around the world
# 554 - Around the world, around the world
# 555 - Around the world, around the world
# 556 - Around the world, around the world
# 557 - Around the world, around the world
# 558 - Around the world, around the world
# 559 - Around the world, around the world
# 560 - Around the world, around the world
# 561 - Around the world, around the world
# 562 - Around the world, around the world
# 563 - Around the world, around the world
# 564 - Around the world, around the world
# 565 - Around the world, around the world
# 566 - Around the world, around the world
# 567 - Around the world, around the world
# 568 - Around the world, around the world
# 569 - Around the world, around the world
# 570 - Around the world, around the world
# 571 - Around the world, around the world
# 572 - Around the world, around the world
# 573 - Around the world, around the world
# 574 - Around the world, around the world
# 575 - Around the world, around the world
# 576 - Around the world, around the world
# 577 - Around the world, around the world
# 578 - Around the world, around the world
# 579 - Around the world, around the world
# 580 - Around the world, around the world
# 581 - Around the world, around the world
# 582 - Around the world, around the world
# 583 - Around the world, around the world
# 584 - Around the world, around the world
# 585 - Around the world, around the world
# 586 - Around the world, around the world
# 587 - Around the world, around the world
# 588 - Around the world, around the world
# 589 - Around the world, around the world
# 590 - Around the world, around the world
# 591 - Around the world, around the world
# 592 - Around the world, around the world
# 593 - Around the world, around the world
# 594 - Around the world, around the world
# 595 - Around the world, around the world
# 596 - Around the world, around the world
# 597 - Around the world, around the world
# 598 - Around the world, around the world
# 599 - Around the world, around the world
# 600 - Around the world, around the world
# 601 - Around the world, around the world
# 602 - Around the world, around the world
# 603 - Around the world, around the world
# 604 - Around the world, around the world
# 605 - Around the world, around the world
# 606 - Around the world, around the world
# 607 - Around the world, around the world
# 608 - Around the world, around the world
# 609 - Around the world, around the world
# 610 - Around the world, around the world
# 611 - Around the world, around the world
# 612 - Around the world, around the world
# 613 - Around the world, around the world
# 614 - Around the world, around the world
# 615 - Around the world, around the world
# 616 - Around the world, around the world
# 617 - Around the world, around the world
# 618 - Around the world, around the world
# 619 - Around the world, around the world
# 620 - Around the world, around the world
# 621 - Around the world, around the world
# 622 - Around the world, around the world
# 623 - Around the world, around the world
# 624 - Around the world, around the world
# 625 - Around the world, around the world
# 626 - Around the world, around the world
# 627 - Around the world, around the world
# 628 - Around the world, around the world
# 629 - Around the world, around the world
# 630 - Around the world, around the world
# 631 - Around the world, around the world
# 632 - Around the world, around the world
# 633 - Around the world, around the world
# 634 - Around the world, around the world
# 635 - Around the world, around the world
# 636 - Around the world, around the world
# 637 - Around the world, around the world
# 638 - Around the world, around the world
# 639 - Around the world, around the world
# 640 - Around the world, around the world
# 641 - Around the world, around the world
# 642 - Around the world, around the world
# 643 - Around the world, around the world
# 644 - Around the world, around the world
# 645 - Around the world, around the world
# 646 - Around the world, around the world
# 647 - Around the world, around the world
# 648 - Around the world, around the world
# 649 - Around the world, around the world
# 650 - Around the world, around the world
# 651 - Around the world, around the world
# 652 - Around the world, around the world
# 653 - Around the world, around the world
# 654 - Around the world, around the world
# 655 - Around the world, around the world
# 656 - Around the world, around the world
# 657 - Around the world, around the world
# 658 - Around the world, around the world
# 659 - Around the world, around the world
# 660 - Around the world, around the world
# 661 - Around the world, around the world
# 662 - Around the world, around the world
# 663 - Around the world, around the world
# 664 - Around the world, around the world
# 665 - Around the world, around the world
# 666 - Around the world, around the world
# 667 - Around the world, around the world
# 668 - Around the world, around the world
# 669 - Around the world, around the world
# 670 - Around the world, around the world
# 671 - Around the world, around the world
# 672 - Around the world, around the world
# 673 - Around the world, around the world
# 674 - Around the world, around the world
# 675 - Around the world, around the world
# 676 - Around the world, around the world
# 677 - Around the world, around the world
# 678 - Around the world, around the world
# 679 - Around the world, around the world
# 680 - Around the world, around the world
# 681 - Around the world, around the world
# 682 - Around the world, around the world
# 683 - Around the world, around the world
# 684 - Around the world, around the world
# 685 - Around the world, around the world
# 686 - Around the world, around the world
# 687 - Around the world, around the world
# 688 - Around the world, around the world
# 689 - Around the world, around the world
# 690 - Around the world, around the world
# 691 - Around the world, around the world
# 692 - Around the world, around the world
# 693 - Around the world, around the world
# 694 - Around the world, around the world
# 695 - Around the world, around the world
# 696 - Around the world, around the world
# 697 - Around the world, around the world
# 698 - Around the world, around the world
# 699 - Around the world, around the world
# 700 - Around the world, around the world
# 701 - Around the world, around the world
# 702 - Around the world, around the world
# 703 - Around the world, around the world
# 704 - Around the world, around the world
# 705 - Around the world, around the world
# 706 - Around the world, around the world
# 707 - Around the world, around the world
# 708 - Around the world, around the world
# 709 - Around the world, around the world
# 710 - Around the world, around the world
# 711 - Around the world, around the world
# 712 - Around the world, around the world
# 713 - Around the world, around the world
# 714 - Around the world, around the world
# 715 - Around the world, around the world
# 716 - Around the world, around the world
# 717 - Around the world, around the world
# 718 - Around the world, around the world
# 719 - Around the world, around the world
# 720 - Around the world, around the world
# 721 - Around the world, around the world
# 722 - Around the world, around the world
# 723 - Around the world, around the world
# 724 - Around the world, around the world
# 725 - Around the world, around the world
# 726 - Around the world, around the world
# 727 - Around the world, around the world
# 728 - Around the world, around the world
# 729 - Around the world, around the world
# 730 - Around the world, around the world
# 731 - Around the world, around the world
# 732 - Around the world, around the world
# 733 - Around the world, around the world
# 734 - Around the world, around the world
# 735 - Around the world, around the world
# 736 - Around the world, around the world
# 737 - Around the world, around the world
# 738 - Around the world, around the world
# 739 - Around the world, around the world
# 740 - Around the world, around the world
# 741 - Around the world, around the world
# 742 - Around the world, around the world
# 743 - Around the world, around the world
# 744 - Around the world, around the world
# 745 - Around the world, around the world
# 746 - Around the world, around the world
# 747 - Around the world, around the world
# 748 - Around the world, around the world
# 749 - Around the world, around the world
# 750 - Around the world, around the world
# 751 - Around the world, around the world
# 752 - Around the world, around the world
# 753 - Around the world, around the world
# 754 - Around the world, around the world
# 755 - Around the world, around the world
# 756 - Around the world, around the world
# 757 - Around the world, around the world
# 758 - Around the world, around the world
# 759 - Around the world, around the world
# 760 - Around the world, around the world
# 761 - Around the world, around the world
# 762 - Around the world, around the world
# 763 - Around the world, around the world
# 764 - Around the world, around the world
# 765 - Around the world, around the world
# 766 - Around the world, around the world
# 767 - Around the world, around the world
# 768 - Around the world, around the world
# 769 - Around the world, around the world
# 770 - Around the world, around the world
# 771 - Around the world, around the world
# 772 - Around the world, around the world
# 773 - Around the world, around the world
# 774 - Around the world, around the world
# 775 - Around the world, around the world
# 776 - Around the world, around the world
# 777 - Around the world, around the world
# 778 - Around the world, around the world
# 779 - Around the world, around the world
# 780 - Around the world, around the world
# 781 - Around the world, around the world
# 782 - Around the world, around the world
# 783 - Around the world, around the world
# 784 - Around the world, around the world
# 785 - Around the world, around the world
# 786 - Around the world, around the world
# 787 - Around the world, around the world
# 788 - Around the world, around the world
# 789 - Around the world, around the world
# 790 - Around the world, around the world
# 791 - Around the world, around the world
# 792 - Around the world, around the world
# 793 - Around the world, around the world
# 794 - Around the world, around the world
# 795 - Around the world, around the world
# 796 - Around the world, around the world
# 797 - Around the world, around the world
# 798 - Around the world, around the world
# 799 - Around the world, around the world
# 800 - Around the world, around the world
# 801 - Around the world, around the world
# 802 - Around the world, around the world
# 803 - Around the world, around the world
# 804 - Around the world, around the world
# 805 - Around the world, around the world
# 806 - Around the world, around the world
# 807 - Around the world, around the world
# 808 - Around the world, around the world
# 809 - Around the world, around the world
# 810 - Around the world, around the world
# 811 - Around the world, around the world
# 812 - Around the world, around the world
# 813 - Around the world, around the world
# 814 - Around the world, around the world
# 815 - Around the world, around the world
# 816 - Around the world, around the world
# 817 - Around the world, around the world
# 818 - Around the world, around the world
# 819 - Around the world, around the world
# 820 - Around the world, around the world
# 821 - Around the world, around the world
# 822 - Around the world, around the world
# 823 - Around the world, around the world
# 824 - Around the world, around the world
# 825 - Around the world, around the world
# 826 - Around the world, around the world
# 827 - Around the world, around the world
# 828 - Around the world, around the world
# 829 - Around the world, around the world
# 830 - Around the world, around the world
# 831 - Around the world, around the world
# 832 - Around the world, around the world
# 833 - Around the world, around the world
# 834 - Around the world, around the world
# 835 - Around the world, around the world
# 836 - Around the world, around the world
# 837 - Around the world, around the world
# 838 - Around the world, around the world
# 839 - Around the world, around the world
# 840 - Around the world, around the world
# 841 - Around the world, around the world
# 842 - Around the world, around the world
# 843 - Around the world, around the world
# 844 - Around the world, around the world
# 845 - Around the world, around the world
# 846 - Around the world, around the world
# 847 - Around the world, around the world
# 848 - Around the world, around the world
# 849 - Around the world, around the world
# 850 - Around the world, around the world
# 851 - Around the world, around the world
# 852 - Around the world, around the world
# 853 - Around the world, around the world
# 854 - Around the world, around the world
# 855 - Around the world, around the world
# 856 - Around the world, around the world
# 857 - Around the world, around the world
# 858 - Around the world, around the world
# 859 - Around the world, around the world
# 860 - Around the world, around the world
# 861 - Around the world, around the world
# 862 - Around the world, around the world
# 863 - Around the world, around the world
# 864 - Around the world, around the world
# 865 - Around the world, around the world
# 866 - Around the world, around the world
# 867 - Around the world, around the world
# 868 - Around the world, around the world
# 869 - Around the world, around the world
# 870 - Around the world, around the world
# 871 - Around the world, around the world
# 872 - Around the world, around the world
# 873 - Around the world, around the world
# 874 - Around the world, around the world
# 875 - Around the world, around the world
# 876 - Around the world, around the world
# 877 - Around the world, around the world
# 878 - Around the world, around the world
# 879 - Around the world, around the world
# 880 - Around the world, around the world
# 881 - Around the world, around the world
# 882 - Around the world, around the world
# 883 - Around the world, around the world
# 884 - Around the world, around the world
# 885 - Around the world, around the world
# 886 - Around the world, around the world
# 887 - Around the world, around the world
# 888 - Around the world, around the world
# 889 - Around the world, around the world
# 890 - Around the world, around the world
# 891 - Around the world, around the world
# 892 - Around the world, around the world
# 893 - Around the world, around the world
# 894 - Around the world, around the world
# 895 - Around the world, around the world
# 896 - Around the world, around the world
# 897 - Around the world, around the world
# 898 - Around the world, around the world
# 899 - Around the world, around the world
# 900 - Around the world, around the world
# 901 - Around the world, around the world
# 902 - Around the world, around the world
# 903 - Around the world, around the world
# 904 - Around the world, around the world
# 905 - Around the world, around the world
# 906 - Around the world, around the world
# 907 - Around the world, around the world
# 908 - Around the world, around the world
# 909 - Around the world, around the world
# 910 - Around the world, around the world
# 911 - Around the world, around the world
# 912 - Around the world, around the world
# 913 - Around the world, around the world
# 914 - Around the world, around the world
# 915 - Around the world, around the world
# 916 - Around the world, around the world
# 917 - Around the world, around the world
# 918 - Around the world, around the world
# 919 - Around the world, around the world
# 920 - Around the world, around the world
# 921 - Around the world, around the world
# 922 - Around the world, around the world
# 923 - Around the world, around the world
# 924 - Around the world, around the world
# 925 - Around the world, around the world
# 926 - Around the world, around the world
# 927 - Around the world, around the world
# 928 - Around the world, around the world
# 929 - Around the world, around the world
# 930 - Around the world, around the world
# 931 - Around the world, around the world
# 932 - Around the world, around the world
# 933 - Around the world, around the world
# 934 - Around the world, around the world
# 935 - Around the world, around the world
# 936 - Around the world, around the world
# 937 - Around the world, around the world
# 938 - Around the world, around the world
# 939 - Around the world, around the world
# 940 - Around the world, around the world
# 941 - Around the world, around the world
# 942 - Around the world, around the world
# 943 - Around the world, around the world
# 944 - Around the world, around the world
# 945 - Around the world, around the world
# 946 - Around the world, around the world
# 947 - Around the world, around the world
# 948 - Around the world, around the world
# 949 - Around the world, around the world
# 950 - Around the world, around the world
# 951 - Around the world, around the world
# 952 - Around the world, around the world
# 953 - Around the world, around the world
# 954 - Around the world, around the world
# 955 - Around the world, around the world
# 956 - Around the world, around the world
# 957 - Around the world, around the world
# 958 - Around the world, around the world
# 959 - Around the world, around the world
# 960 - Around the world, around the world
# 961 - Around the world, around the world
# 962 - Around the world, around the world
# 963 - Around the world, around the world
# 964 - Around the world, around the world
# 965 - Around the world, around the world
# 966 - Around the world, around the world
# 967 - Around the world, around the world
# 968 - Around the world, around the world
# 969 - Around the world, around the world
# 970 - Around the world, around the world
# 971 - Around the world, around the world
# 972 - Around the world, around the world
# 973 - Around the world, around the world
# 974 - Around the world, around the world
# 975 - Around the world, around the world
# 976 - Around the world, around the world
# 977 - Around the world, around the world
# 978 - Around the world, around the world
# 979 - Around the world, around the world
# 980 - Around the world, around the world
# 981 - Around the world, around the world
# 982 - Around the world, around the world
# 983 - Around the world, around the world
# 984 - Around the world, around the world
# 985 - Around the world, around the world
# 986 - Around the world, around the world
# 987 - Around the world, around the world
# 988 - Around the world, around the world
# 989 - Around the world, around the world
# 990 - Around the world, around the world
# 991 - Around the world, around the world
# 992 - Around the world, around the world
# 993 - Around the world, around the world
# 994 - Around the world, around the world
# 995 - Around the world, around the world
# 996 - Around the world, around the world
# 997 - Around the world, around the world
# 998 - Around the world, around the world
# 999 - Around the world, around the world
# 1000 - Around the world, around the world
# 1001 - Around the world, around the world
# 1002 - Around the world, around the world
# 1003 - Around the world, around the world
# 1004 - Around the world, around the world
# 1005 - Around the world, around the world
# 1006 - Around the world, around the world
# 1007 - Around the world, around the world
# 1008 - Around the world, around the world
# 1009 - Around the world, around the world
# 1010 - Around the world, around the world
# 1011 - Around the world, around the world
# 1012 - Around the world, around the world
# 1013 - Around the world, around the world
# 1014 - Around the world, around the world
# 1015 - Around the world, around the world
# 1016 - Around the world, around the world
# 1017 - Around the world, around the world
# 1018 - Around the world, around the world
# 1019 - Around the world, around the world
# 1020 - Around the world, around the world
# 1021 - Around the world, around the world
# 1022 - Around the world, around the world
# 1023 - Around the world, around the world
# 1024 - Around the world, around the world
# 1025 - Around the world, around the world
# 1026 - Around the world, around the world
# 1027 - Around the world, around the world
# 1028 - Around the world, around the world
# 1029 - Around the world, around the world
# 1030 - Around the world, around the world
# 1031 - Around the world, around the world
# 1032 - Around the world, around the world
# 1033 - Around the world, around the world
# 1034 - Around the world, around the world
# 1035 - Around the world, around the world
# 1036 - Around the world, around the world
# 1037 - Around the world, around the world
# 1038 - Around the world, around the world
# 1039 - Around the world, around the world
# 1040 - Around the world, around the world
# 1041 - Around the world, around the world
# 1042 - Around the world, around the world
# 1043 - Around the world, around the world
# 1044 - Around the world, around the world
# 1045 - Around the world, around the world
# 1046 - Around the world, around the world
# 1047 - Around the world, around the world
# 1048 - Around the world, around the world
# 1049 - Around the world, around the world
# 1050 - Around the world, around the world
# 1051 - Around the world, around the world
# 1052 - Around the world, around the world
# 1053 - Around the world, around the world
# 1054 - Around the world, around the world
# 1055 - Around the world, around the world
# 1056 - Around the world, around the world
# 1057 - Around the world, around the world
# 1058 - Around the world, around the world
# 1059 - Around the world, around the world
# 1060 - Around the world, around the world
# 1061 - Around the world, around the world
# 1062 - Around the world, around the world
# 1063 - Around the world, around the world
# 1064 - Around the world, around the world
# 1065 - Around the world, around the world
# 1066 - Around the world, around the world
# 1067 - Around the world, around the world
# 1068 - Around the world, around the world
# 1069 - Around the world, around the world
# 1070 - Around the world, around the world
# 1071 - Around the world, around the world
# 1072 - Around the world, around the world
# 1073 - Around the world, around the world
# 1074 - Around the world, around the world
# 1075 - Around the world, around the world
# 1076 - Around the world, around the world
# 1077 - Around the world, around the world
# 1078 - Around the world, around the world
# 1079 - Around the world, around the world
# 1080 - Around the world, around the world
# 1081 - Around the world, around the world
# 1082 - Around the world, around the world
# 1083 - Around the world, around the world
# 1084 - Around the world, around the world
# 1085 - Around the world, around the world
# 1086 - Around the world, around the world
# 1087 - Around the world, around the world
# 1088 - Around the world, around the world
# 1089 - Around the world, around the world
# 1090 - Around the world, around the world
# 1091 - Around the world, around the world
# 1092 - Around the world, around the world
# 1093 - Around the world, around the world
# 1094 - Around the world, around the world
# 1095 - Around the world, around the world
# 1096 - Around the world, around the world
# 1097 - Around the world, around the world
# 1098 - Around the world, around the world
# 1099 - Around the world, around the world
# 1100 - Around the world, around the world
# 1101 - Around the world, around the world
# 1102 - Around the world, around the world
# 1103 - Around the world, around the world
# 1104 - Around the world, around the world
# 1105 - Around the world, around the world
# 1106 - Around the world, around the world
# 1107 - Around the world, around the world
# 1108 - Around the world, around the world
# 1109 - Around the world, around the world
# 1110 - Around the world, around the world
# 1111 - Around the world, around the world
# 1112 - Around the world, around the world
# 1113 - Around the world, around the world
# 1114 - Around the world, around the world
# 1115 - Around the world, around the world
# 1116 - Around the world, around the world
# 1117 - Around the world, around the world
# 1118 - Around the world, around the world
# 1119 - Around the world, around the world
# 1120 - Around the world, around the world
# 1121 - Around the world, around the world
# 1122 - Around the world, around the world
# 1123 - Around the world, around the world
# 1124 - Around the world, around the world
# 1125 - Around the world, around the world
# 1126 - Around the world, around the world
# 1127 - Around the world, around the world
# 1128 - Around the world, around the world
# 1129 - Around the world, around the world
# 1130 - Around the world, around the world
# 1131 - Around the world, around the world
# 1132 - Around the world, around the world
# 1133 - Around the world, around the world
# 1134 - Around the world, around the world
# 1135 - Around the world, around the world
# 1136 - Around the world, around the world
# 1137 - Around the world, around the world
# 1138 - Around the world, around the world
# 1139 - Around the world, around the world
# 1140 - Around the world, around the world
# 1141 - Around the world, around the world
# 1142 - Around the world, around the world
# 1143 - Around the world, around the world
# 1144 - Around the world, around the world
# 1145 - Around the world, around the world
# 1146 - Around the world, around the world
# 1147 - Around the world, around the world
# 1148 - Around the world, around the world
# 1149 - Around the world, around the world
# 1150 - Around the world, around the world
# 1151 - Around the world, around the world
# 1152 - Around the world, around the world
# 1153 - Around the world, around the world
# 1154 - Around the world, around the world
# 1155 - Around the world, around the world
# 1156 - Around the world, around the world
# 1157 - Around the world, around the world
# 1158 - Around the world, around the world
# 1159 - Around the world, around the world
# 1160 - Around the world, around the world
# 1161 - Around the world, around the world
# 1162 - Around the world, around the world
# 1163 - Around the world, around the world
# 1164 - Around the world, around the world
# 1165 - Around the world, around the world
# 1166 - Around the world, around the world
# 1167 - Around the world, around the world
# 1168 - Around the world, around the world
# 1169 - Around the world, around the world
# ...
# 4135 - Around the world, around the world
# 4136 - Around the world, around the world
# 4137 - Around the world, around the world
# 4138 - Around the world, around the world
# 4139 - Around the world, around the world
# 4140 - Around the world, around the world
# 4141 - Around the world, around the world
# 4142 - Around the world, around the world
# 4143 - Around the world, around the world
# 4144 - Around the world, around the world
# 4145 - Around the world, around the world
# 4146 - Around the world, around the world
# 4147 - Around the world, around the world
# 4148 - Around the world, around the world
# 4149 - Around the world, around the world
# 4150 - Around the world, around the world
# 4151 - Around the world, around the world
# 4152 - Around the world, around the world
# 4153 - Around the world, around the world
# 4154 - Around the world, around the world
# 4155 - Around the world, around the world
# 4156 - Around the world, around the world
# 4157 - Around the world, around the world
# 4158 - Around the world, around the world
# 4159 - Around the world, around the world
# 4160 - Around the world, around the world
# 4161 - Around the world, around the world
# 4162 - Around the world, around the world
# 4163 - Around the world, around the world
# 4164 - Around the world, around the world
# 4165 - Around the world, around the world
# 4166 - Around the world, around the world
# 4167 - Around the world, around the world
# 4168 - Around the world, around the world
# 4169 - Around the world, around the world
# 4170 - Around the world, around the world
# 4171 - Around the world, around the world
# 4172 - Around the world, around the world
# 4173 - Around the world, around the world
# 4174 - Around the world, around the world
# 4175 - Around the world, around the world
# 4176 - Around the world, around the world
# 4177 - Around the world, around the world
# 4178 - Around the world, around the world
# 4179 - Around the world, around the world
# 4180 - Around the world, around the world
# 4181 - Around the world, around the world
# 4182 - Around the world, around the world
# 4183 - Around the world, around the world
# 4184 - Around the world, around the world
# 4185 - Around the world, around the world
# 4186 - Around the world, around the world
# 4187 - Around the world, around the world
# 4188 - Around the world, around the world
# 4189 - Around the world, around the world
# 4190 - Around the world, around the world
# 4191 - Around the world, around the world
# 4192 - Around the world, around the world
# 4193 - Around the world, around the world
# 4194 - Around the world, around the world
# 4195 - Around the world, around the world
# 4196 - Around the world, around the world
# 4197 - Around the world, around the world
# 4198 - Around the world, around the world
# 4199 - Around the world, around the world
# 4200 - Around the world, around the world
# 4201 - Around the world, around the world
# 4202 - Around the world, around the world
# 4203 - Around the world, around the world
# 4204 - Around the world, around the world
# 4205 - Around the world, around the world
# 4206 - Around the world, around the world
# 4207 - Around the world, around the world
# 4208 - Around the world, around the world
# 4209 - Around the world, around the world
# 4210 - Around the world, around the world
# 4211 - Around the world, around the world
# 4212 - Around the world, around the world
# 4213 - Around the world, around the world
# 4214 - Around the world, around the world
# 4215 - Around the world, around the world
# 4216 - Around the world, around the world
# 4217 - Around the world, around the world
# 4218 - Around the world, around the world
# 4219 - Around the world, around the world
# 4220 - Around the world, around the world
# 4221 - Around the world, around the world
# 4222 - Around the world, around the world
# 4223 - Around the world, around the world
# 4224 - Around the world, around the world
# 4225 - Around the world, around the world
# 4226 - Around the world, around the world
# 4227 - Around the world, around the world
# 4228 - Around the world, around the world
# 4229 - Around the world, around the world
# 4230 - Around the world, around the world
# 4231 - Around the world, around the world
# 4232 - Around the world, around the world
# 4233 - Around the world, around the world
# 4234 - Around the world, around the world
# 4235 - Around the world, around the world
# 4236 - Around the world, around the world
# 4237 - Around the world, around the world
# 4238 - Around the world, around the world
# 4239 - Around the world, around the world
# 4240 - Around the world, around the world
# 4241 - Around the world, around the world
# 4242 - Around the world, around the world
# 4243 - Around the world, around the world
# 4244 - Around the world, around the world
# 4245 - Around the world, around the world
# 4246 - Around the world, around the world
# 4247 - Around the world, around the world
# 4248 - Around the world, around the world
# 4249 - Around the world, around the world
# 4250 - Around the world, around the world
# 4251 - Around the world, around the world
# 4252 - Around the world, around the world
# 4253 - Around the world, around the world
# 4254 - Around the world, around the world
# 4255 - Around the world, around the world
# 4256 - Around the world, around the world
# 4257 - Around the world, around the world
# 4258 - Around the world, around the world
# 4259 - Around the world, around the world
# 4260 - Around the world, around the world
# 4261 - Around the world, around the world
# 4262 - Around the world, around the world
# 4263 - Around the world, around the world
# 4264 - Around the world, around the world
# 4265 - Around the world, around the world
# 4266 - Around the world, around the world
# 4267 - Around the world, around the world
# 4268 - Around the world, around the world
# 4269 - Around the world, around the world
# 4270 - Around the world, around the world
# 4271 - Around the world, around the world
# 4272 - Around the world, around the world
# 4273 - Around the world, around the world
# 4274 - Around the world, around the world
# 4275 - Around the world, around the world
# 4276 - Around the world, around the world
# 4277 - Around the world, around the world
# 4278 - Around the world, around the world
# 4279 - Around the world, around the world
# 4280 - Around the world, around the world
# 4281 - Around the world, around the world
# 4282 - Around the world, around the world
# 4283 - Around the world, around the world
# 4284 - Around the world, around the world
# 4285 - Around the world, around the world
# 4286 - Around the world, around the world
# 4287 - Around the world, around the world
# 4288 - Around the world, around the world
# 4289 - Around the world, around the world
# 4290 - Around the world, around the world
# 4291 - Around the world, around the world
# 4292 - Around the world, around the world
# 4293 - Around the world, around the world
# 4294 - Around the world, around the world
# 4295 - Around the world, around the world
# 4296 - Around the world, around the world
# 4297 - Around the world, around the world
# 4298 - Around the world, around the world
# 4299 - Around the world, around the world
# 4300 - Around the world, around the world
# 4301 - Around the world, around the world
# 4302 - Around the world, around the world
# 4303 - Around the world, around the world
# 4304 - Around the world, around the world
# 4305 - Around the world, around the world
# 4306 - Around the world, around the world
# 4307 - Around the world, around the world
# 4308 - Around the world, around the world
# 4309 - Around the world, around the world
# 4310 - Around the world, around the world
# 4311 - Around the world, around the world
# 4312 - Around the world, around the world
# 4313 - Around the world, around the world
# 4314 - Around the world, around the world
# 4315 - Around the world, around the world
# 4316 - Around the world, around the world
# 4317 - Around the world, around the world
# 4318 - Around the world, around the world
# 4319 - Around the world, around the world
# 4320 - Around the world, around the world
# 4321 - Around the world, around the world
# 4322 - Around the world, around the world
# 4323 - Around the world, around the world
# 4324 - Around the world, around the world
# 4325 - Around the world, around the world
# 4326 - Around the world, around the world
# 4327 - Around the world, around the world
# 4328 - Around the world, around the world
# 4329 - Around the world, around the world
# 4330 - Around the world, around the world
# 4331 - Around the world, around the world
# 4332 - Around the world, around the world
# 4333 - Around the world, around the world
# 4334 - Around the world, around the world
# 4335 - Around the world, around the world
# 4336 - Around the world, around the world
# 4337 - Around the world, around the world
# 4338 - Around the world, around the world
# 4339 - Around the world, around the world
# 4340 - Around the world, around the world
# 4341 - Around the world, around the world
# 4342 - Around the world, around the world
# 4343 - Around the world, around the world
# 4344 - Around the world, around the world
# 4345 - Around the world, around the world
# 4346 - Around the world, around the world
# 4347 - Around the world, around the world
# 4348 - Around the world, around the world
# 4349 - Around the world, around the world
# 4350 - Around the world, around the world
# 4351 - Around the world, around the world
# 4352 - Around the world, around the world
# 4353 - Around the world, around the world
# 4354 - Around the world, around the world
# 4355 - Around the world, around the world
# 4356 - Around the world, around the world
# 4357 - Around the world, around the world
# 4358 - Around the world, around the world
# 4359 - Around the world, around the world
# 4360 - Around the world, around the world
# 4361 - Around the world, around the world
# 4362 - Around the world, around the world
# 4363 - Around the world, around the world
# 4364 - Around the world, around the world
# 4365 - Around the world, around the world
# 4366 - Around the world, around the world
# 4367 - Around the world, around the world
# 4368 - Around the world, around the world
# 4369 - Around the world, around the world
# 4370 - Around the world, around the world
# 4371 - Around the world, around the world
# 4372 - Around the world, around the world
# 4373 - Around the world, around the world
# 4374 - Around the world, around the world
# 4375 - Around the world, around the world
# 4376 - Around the world, around the world
# 4377 - Around the world, around the world
# 4378 - Around the world, around the world
# 4379 - Around the world, around the world
# 4380 - Around the world, around the world
# 4381 - Around the world, around the world
# 4382 - Around the world, around the world
# 4383 - Around the world, around the world
# 4384 - Around the world, around the world
# 4385 - Around the world, around the world
# 4386 - Around the world, around the world
# 4387 - Around the world, around the world
# 4388 - Around the world, around the world
# 4389 - Around the world, around the world
# 4390 - Around the world, around the world
# 4391 - Around the world, around the world
# 4392 - Around the world, around the world
# 4393 - Around the world, around the world
# 4394 - Around the world, around the world
# 4395 - Around the world, around the world
# 4396 - Around the world, around the world
# 4397 - Around the world, around the world
# 4398 - Around the world, around the world
# 4399 - Around the world, around the world
# 4400 - Around the world, around the world
# 4401 - Around the world, around the world
# 4402 - Around the world, around the world
# 4403 - Around the world, around the world
# 4404 - Around the world, around the world
# 4405 - Around the world, around the world
# 4406 - Around the world, around the world
# 4407 - Around the world, around the world
# 4408 - Around the world, around the world
# 4409 - Around the world, around the world
# 4410 - Around the world, around the world
# 4411 - Around the world, around the world
# 4412 - Around the world, around the world
# 4413 - Around the world, around the world
# 4414 - Around the world, around the world
# 4415 - Around the world, around the world
# 4416 - Around the world, around the world
# 4417 - Around the world, around the world
# 4418 - Around the world, around the world
# 4419 - Around the world, around the world
# 4420 - Around the world, around the world
# 4421 - Around the world, around the world
# 4422 - Around the world, around the world
# 4423 - Around the world, around the world
# 4424 - Around the world, around the world
# 4425 - Around the world, around the world
# 4426 - Around the world, around the world
# 4427 - Around the world, around the world
# 4428 - Around the world, around the world
# 4429 - Around the world, around the world
# 4430 - Around the world, around the world
# 4431 - Around the world, around the world
# 4432 - Around the world, around the world
# 4433 - Around the world, around the world
# 4434 - Around the world, around the world
# 4435 - Around the world, around the world
# 4436 - Around the world, around the world
# 4437 - Around the world, around the world
# 4438 - Around the world, around the world
# 4439 - Around the world, around the world
# 4440 - Around the world, around the world
# 4441 - Around the world, around the world
# 4442 - Around the world, around the world
# 4443 - Around the world, around the world
# 4444 - Around the world, around the world
# 4445 - Around the world, around the world
# 4446 - Around the world, around the world
# 4447 - Around the world, around the world
# 4448 - Around the world, around the world
# 4449 - Around the world, around the world
# 4450 - Around the world, around the world
# 4451 - Around the world, around the world
# 4452 - Around the world, around the world
# 4453 - Around the world, around the world
# 4454 - Around the world, around the world
# 4455 - Around the world, around the world
# 4456 - Around the world, around the world
# 4457 - Around the world, around the world
# 4458 - Around the world, around the world
# 4459 - Around the world, around the world
# 4460 - Around the world, around the world
# 4461 - Around the world, around the world
# 4462 - Around the world, around the world
# 4463 - Around the world, around the world
# 4464 - Around the world, around the world
# 4465 - Around the world, around the world
# 4466 - Around the world, around the world
# 4467 - Around the world, around the world
# 4468 - Around the world, around the world
# 4469 - Around the world, around the world
# 4470 - Around the world, around the world
# 4471 - Around the world, around the world
# 4472 - Around the world, around the world
# 4473
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-e943d6d0a762> in <cell line: 1>()
# ----> 1 endless_loop()
#
# <ipython-input-44-cd700efee05a> in endless_loop()
#       2     num = 1
#       3     while num >= 0:
# ----> 4         print(num,"- Around the world, around the world")
#       5         num += 1
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.9/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.9/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# The reason this loop is endless is that the threshold (num >= 0) is always true. Since num starts at 1 and increases with every iteration the loop will continue to print infinite output.

# %% [markdown]
# To give one last example of how a while loop should be done:

# %%
def print_multiples_of_7(x):
    count = 0
    while count < x:
        count += 1
        print( count*7 )
    print( "Done" )

print_multiples_of_7(10)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# Done

# %% [markdown]
# ### For loops
# So now you know *while* loops and how they can be used. Next up is the **for** loop. A *for* loop has boundaries with a list in which it loops between which makes it a bit easier to use.
#
# ```
# for <variable> in <list>:
#     <statements>
# ```
#
#
#
# In order to use a **for** loop it is necessary to know the *range()* function. This function creates a list of values between the indicated values and these values are assigned to the iterating variable of the foor loop respectively according to the list.

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3,6):
    print(i)
# Out:
# 3
# 4
# 5

# %% [markdown]
# When you pass a third variable to the *range()* function this will be the distance between the values in the list. For example when you pass 3 as the third variable, the values in the list will go 3 by 3.

# %%
for i in range(0,10,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9

# %% [markdown]
# You can also iterate in reverse when you pass a negative value as the third parameter.

# %%
for i in range(10,0,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %% [markdown]
# As you can see the **for** loop iterates over all the values in the list that you give. **For** loops are also very useful when you are dealing with text data. This is the case because strings are defined as letter (character) lists on Python. So when you pass a text to a for loop to iterate over, it goes over each letter of the string. We'll talk more about lists in the next section.

# %%
def count_vowels(text):
    vowels = 0
    for i in text:
        if i == "a":
            vowels += 1
        if i == "e":
            vowels += 1
        if i == "o":
            vowels += 1
        if i == "i":
            vowels += 1
        if i == "u":
            vowels += 1
        else:
            continue
    return vowels

count_vowels("hi everyone")
# Out:
# 5

# %% [markdown]
# ## 7. Lists and Dictionaries

# %% [markdown]
# The final concepts we'll learn in this notebook are *lists* and *dictionaries*. Both of these structures are designed to store multiple items in a single variable. Lists and dictionaries are similar to each other they are designed to focus on easing different objectives.

# %% [markdown]
# ### Lists
#
# Lists are collections of elements that you can store in a variable. The items in a list are ordered. A list can be created with square brackets ([]).

# %%
groceries = ['banana','cereal','soda','cake']
groceries
# Out:
# ['banana', 'cereal', 'soda', 'cake']

# %% [markdown]
# You can get the item in a list by using its index. Note that the indeces in lists start from 0 and end at (# of items -1)

# %%
print("First element is" , groceries[0])
print("Last element is" , groceries[3]) # number of elements (length of the list) is 4 so last item is at 3
# Out:
# First element is banana
# Last element is cake

# %% [markdown]
# The fun thing with lists is that you can use loops to go through them:

# %%
def find_groceries_with_an_e(grocery_list):
    with_e = list()
    for x in grocery_list:
        if 'e' in x:
            with_e.append(x)
    return with_e

find_groceries_with_an_e(groceries)
# Out:
# ['cereal', 'cake']

# %% [markdown]
# #### List methods

# %% [markdown]
# As mentioned above, lists and dictionaries are designed to ease some objectives and in order to achieve this, they need to have some generic built-in *methods* that provide the most commonly used functions of these structures
#
# For instance, you probably noticed the **.append()** function that was used in the last block. This function is used to add elements to a list.

# %%
print(groceries)
groceries.append("bread")
print(groceries)
# Out:
# ['banana', 'cereal', 'soda', 'cake']
# ['banana', 'cereal', 'soda', 'cake', 'bread']

# %% [markdown]
# Some other usefull functions are:
# - **.insert()**: Adds an element in the desired location.
# - **.remove()**: Removes an element.
# - **.pop()**: Also removes an element but by index.
# - **.sort()**: sorts the list in alphabetic order, or from low to high.
#
# You can find more methods with explanations here: https://docs.python.org/3/tutorial/datastructures.html
#
# Examples:

# %%
groceries.insert(2,"milk")
groceries
# Out:
# ['banana', 'cereal', 'milk', 'soda', 'cake', 'bread']

# %%
groceries.remove("cereal")
groceries
# Out:
# ['banana', 'milk', 'soda', 'cake', 'bread']

# %%
groceries.pop(2)
groceries
# Out:
# ['banana', 'milk', 'cake', 'bread']

# %%
groceries.sort()
groceries
# Out:
# ['banana', 'bread', 'cake', 'milk']

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionaries differ from lists in the sense that dictionaries are unordered, and they consist of key and value pairs. Dictionaries can be created using the curly brackets ({}).

# %%
inventory = {"nike":35,"puma":23,"adidas":80}
inventory["nike"]
# Out:
# 35

# %% [markdown]
# Dictionaries are useful because you can store values for different keys. So that, later on, you can easily find the information you need.

# %%
for i in inventory:
    print(i, ":", inventory[i])
# Out:
# nike : 35
# puma : 23
# adidas : 80

# %% [markdown]
# As you can see you can call back the information that you need by using brackets ([]). Adding information to your dictionary works in a similar way:

# %%
inventory["asics"] = 45
inventory
# Out:
# {'nike': 35, 'puma': 23, 'adidas': 80, 'asics': 45}

# %% [markdown]
# Now let's say, your shop had a good day and you sold 25 Nikes, 7 Pumas, 21 adidas & 10 Asics:

# %%
inventory["nike"] -= 25 
inventory["puma"] -= 7 
inventory["adidas"] -= 21 
inventory["asics"] -= 10
inventory
# Out:
# {'nike': 10, 'puma': 16, 'adidas': 59, 'asics': 35}

# %% [markdown]
# You can use dictionaries to clean up lists and make them more readable

# %%
all_shoes = ["nike Air Force 1","nike Air Max 1","Nike Waffle Racer","Nike Cortez","Nike Air Max 90","Nike Air Mag","Nike Air Yeezy","Air Jordan 3","Nike Blazer","Nike Air Max 97","Nike Flyknit Racer",
             "Nike Dunk SB","Nike Air Foamposite","Nike Zoom Spiridon","Nike Air Stab","Nike Kobe 4","Nike Pegasus","Nike Air Presto","Nike Hyperdunk","Nike Kobe 5","Nike Free 5.0",'Air Jordan 6',
             "Nike Air Safari","Nike Challenge Court","Nike Air Mowabb","Nike Air Flight 89","Nike Air Zoom Generation", "Parley x Adidas Ultraboost 6.0.","Adidas Gazelle","Adidas Samba","Adidas Yeezy Powerphase",
             "Adidas NMD_R1","Adidas Pharrell Hu NMD","Adidas Yeezy Boost 350 V2","adidas Superstar", "Puma Future Rider","Puma RS-X","Puma Suede Classic", "Puma RS-X3","Puma Roma","Puma Pacer Next Cage",
             "Puma Smash v2","Puma Mirage Tech"]

def shoes_in_inventory(all_shoes):
    invent = {'nike':0,'puma':0,"adidas":0}
    for shoe in all_shoes:
        if 'nike' in shoe.lower(): #lower() function transforms all letters in a string into lowercase letters
            invent["nike"] += 1
        if 'adidas' in shoe.lower():
            invent["adidas"] += 1
        if 'puma' in shoe.lower():
            invent["puma"] += 1
    return invent

shoes_in_inventory(all_shoes)
# Out:
# {'nike': 25, 'puma': 8, 'adidas': 8}

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1. Cash

# %% [markdown]
# You are given a large number of cents. Write a function that calculates the amount of cash that you have gained in coins (for this exercise you only have to use Euros, 50 cents, 20 cents, and 1 cent). So for example your input is 1753 cents. Then your output should be 17 euros, 1 fifty cents, 0 twenty cents & 3 cents.

# %%
def cash_gain(amount):
  """
   Returns the amount of cash gained in coins.

   Args:
   amount: int. An amount of cash.

   Returns:
   output: str. The amount of cash in number of coins (euros, 50 cents, 20 cents, cent)
  """
  euro = amount // 100 #1 euro = 100 cents
  cents_50 = (amount - (euro * 100)) // 50
  cents_20 = (amount - (euro * 100) - (cents_50 * 50)) // 20
  cent = (amount - (euro * 100)) - (cents_50 * 50) - (cents_20 * 20)

  output = "There are {euro} euros, {cents_50} fifty cents, {cents_20} twenty cents, {cent} one cent."\
  .format(euro=euro, cents_50=cents_50, cents_20=cents_20, cent=cent)
  print(output)


##Function execution
cash_gain(1753)
# Out:
# There are 17 euros, 1 fifty cents, 0 twenty cents, 3 one cent.

# %% [markdown]
# ### 2. Vowels

# %% [markdown]
# Write a function that takes text as an input and returns the number of unique vowels in that text. So for example "I like python, it is so cool" outputs 3 vowels (y is not considered a vowel here)

# %%
def vowels (text):
  """
   Returns the number of unique vowels in the provided text.

   Args:
   text: str. A text.

   Returns:
   z: int. Number of unique vowels
  """
  ##Vowels
  set_vowels = {'a', 'e', 'i', 'o', 'u'}

  ##Turns "text" into a set
  text2 = set(text)

  ##Intersection between both sets
  z = text2.intersection(set_vowels)

  return len(z)


##Function execution
vowels("I like python, it is so cool")
# Out:
# 3

# %% [markdown]
# ### 3. Fibonacci

# %% [markdown]
# Write a function that prints all the numbers in a Fibonacci sequence (if you don't know the Fibonacci sequence you can look it up) until it reaches a maximal point. So for example, your input is 50 then the output should be 1,1,2,3,5,8,13,21,34
#
# **Hint**: use a loop

# %% [markdown]
# ### 4.1 Lists & Dictionaries

# %% [markdown]
# Write 3 functions that will find the highest, lowest, and most common value in a list of values. So for example your given the input [3,9,5,7,1,9,2,5,9,6,2,33,5,78,9,4,3,9,-1] then the output should be highest: 78, lowest: -1, most common: 9

# %% [markdown]
# ### 4.2 Lists & Dictionaries

# %% [markdown]
# Write a function that takes a text, splits it into words, and case-insensitively builds a dictionary that stores for every word how often it occurs in the text. Then print all the words with their quantities in alphabetical order.
#
# **Hint**: look up the .split() and .strip() functions

# %%
# AI generated poem:
text = """and soon I am staring out again 
begin to practise my words, expecting my word 
will come. it will not. the wind is calling. 
my friend is near, I hear his breath. 
his breath is not the air. he touches me again with his hands
and tells me I am growing old, he says, far old. 
we travel across an empty field in my heart. 
there is nothing in the dark, I think, but he. 
I close my eyes and try to remember what I was. 
he says it was an important and interesting day, 
because I put in his hands one night 
the box of light that had been a tree."""
